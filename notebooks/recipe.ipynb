# %%
# ============================================
# 🎯 GOOGLE COLAB - TEST GEMINI API (FIXED)
# Tạo công thức bánh ngọt theo trend & insight
# ============================================

# ✅ Bước 1: Cài đặt thư viện
# !pip install google-generativeai -q

# ✅ Bước 2: Import và setup
import google.generativeai as genai
# from google.colab import userdata
import json
import time

# ✅ Bước 3: Cấu hình API Key

GEMINI_API_KEY = 'AIzaSyAkGgbqhI-1frAudws0C7r-T50g1QFusXM'

genai.configure(api_key=GEMINI_API_KEY)

# ✅ Bước 4: Tạo hàm helper
def test_gemini_basic():
    """Test cơ bản xem API hoạt động không"""
    model = genai.GenerativeModel('gemini-2.5-pro')
    response = model.generate_content("Hello, can you help me?")
    print("🤖 Gemini response:", response.text[:100] + "...")
    return response.text

def generate_recipe_from_trend(trend, user_segment, occasion="everyday", language="Vietnamese"):
    """Tạo công thức bánh từ trend và phân khúc người dùng"""

    model = genai.GenerativeModel('gemini-2.5-pro')

    prompt = f"""
Bạn là một đầu bếp bánh ngọt chuyên nghiệp và chuyên gia marketing.

NHIỆM VỤ: Tạo công thức bánh ngọt phù hợp với:
- Xu hướng (Trend): {trend}
- Đối tượng khách hàng: {user_segment}
- Dịp/Sự kiện: {occasion}

YÊU CẦU OUTPUT (bằng tiếng {language}):
1. TÊN BÁNH: Tên sáng tạo, bắt trend
2. MÔ TẢ: 2-3 câu giới thiệu món bánh
3. NGUYÊN LIỆU: Danh sách chi tiết kèm định lượng
4. CÁCH LÀM: Hướng dẫn từng bước
5. GỢI Ý TRANG TRÍ: Phù hợp với trend
6. CAPTION FACEBOOK: 1 đoạn ngắn viral để đăng bán

Hãy sáng tạo và đảm bảo công thức khả thi cho tiệm bánh nhỏ.
"""

    response = model.generate_content(prompt)
    return response.text

def generate_recipe_from_ingredients(ingredients, language="Vietnamese"):
    """Tạo công thức từ danh sách nguyên liệu"""

    model = genai.GenerativeModel('gemini-2.5-pro')

    prompt = f"""
Với các nguyên liệu sau: {ingredients}

Hãy tạo một công thức bánh ngọt đơn giản bằng tiếng {language}, bao gồm:
1. Tên món
2. Các bước thực hiện chi tiết
3. Thời gian và nhiệt độ nướng (nếu cần)
4. Lưu ý quan trọng
"""

    response = model.generate_content(prompt)
    return response.text

# ✅ Bước 5: Test thử các chức năng
print("=" * 50)
print("🧪 TEST 1: Kiểm tra kết nối Gemini")
print("=" * 50)
test_gemini_basic()

print("\n" + "=" * 50)
print("🎂 TEST 2: Tạo công thức theo TREND")
print("=" * 50)

# Ví dụ 1: Bánh trend Labubu cho GenZ
recipe1 = generate_recipe_from_trend(
    trend="Labubu (nhân vật hot trend)",
    user_segment="GenZ (18-25 tuổi, thích màu pastel, cute)",
    occasion="Sinh nhật",
    language="Vietnamese"
)
print(recipe1)

print("\n" + "=" * 50)
print("🥧 TEST 3: Tạo công thức từ NGUYÊN LIỆU")
print("=" * 50)

# Ví dụ 2: Từ nguyên liệu có sẵn
recipe2 = generate_recipe_from_ingredients(
    ingredients="bột mì, trứng, đường, bơ, sữa tươi, vani, baking powder",
    language="Vietnamese"
)
print(recipe2)

# ✅ Bước 6: Test nâng cao - Nhiều scenarios
print("\n" + "=" * 50)
print("🌟 TEST 4: Các scenarios khác nhau")
print("=" * 50)

test_cases = [
    {
        "trend": "Doraemon",
        "user_segment": "Trẻ em 5-12 tuổi",  # Đã sửa từ 'segment' thành 'user_segment'
        "occasion": "Trung Thu"
    },
    {
        "trend": "Minimalist, healthy",
        "user_segment": "Dân gym, người ăn kiêng",
        "occasion": "Hàng ngày"
    },
    {
        "trend": "Hoa anh đào Nhật Bản",
        "user_segment": "Phụ nữ 25-40, thích phong cách Nhật",
        "occasion": "Valentine"
    }
]

for i, test in enumerate(test_cases, 1):
    print(f"\n--- Scenario {i}: {test['trend']} ---")
    try:
        result = generate_recipe_from_trend(**test)
        # In 500 ký tự đầu để demo
        print(result[:500] + "...\n")
        time.sleep(2)  # Tránh rate limit
    except Exception as e:
        print(f"❌ Lỗi: {e}")

# ✅ Bước 7: Tạo giao diện tương tác đơn giản
print("\n" + "=" * 50)
print("🎮 INTERACTIVE MODE")
print("=" * 50)

def interactive_recipe_generator():
    """Giao diện tương tác để test"""
    print("Chọn chế độ:")
    print("1. Tạo công thức từ TREND")
    print("2. Tạo công thức từ NGUYÊN LIỆU")

    choice = input("\nNhập lựa chọn (1 hoặc 2): ")

    if choice == "1":
        trend = input("Nhập trend/xu hướng: ")
        user_segment = input("Nhập đối tượng khách hàng: ")
        occasion = input("Nhập dịp/sự kiện (hoặc Enter để bỏ qua): ") or "hàng ngày"

        print("\n⏳ Đang tạo công thức...")
        result = generate_recipe_from_trend(trend, user_segment, occasion)
        print("\n📝 KẾT QUẢ:\n")
        print(result)

    elif choice == "2":
        ingredients = input("Nhập danh sách nguyên liệu (cách nhau bằng dấu phẩy): ")

        print("\n⏳ Đang tạo công thức...")
        result = generate_recipe_from_ingredients(ingredients)
        print("\n📝 KẾT QUẢ:\n")
        print(result)

    else:
        print("Lựa chọn không hợp lệ!")

# Uncomment dòng dưới để chạy interactive mode
# interactive_recipe_generator()

# ✅ Bước 8: Export kết quả (optional)
def save_recipe_to_file(recipe_text, filename="recipe_output.txt"):
    """Lưu công thức ra file"""
    with open(filename, 'w', encoding='utf-8') as f:
        f.write(recipe_text)
    print(f"✅ Đã lưu công thức vào file: {filename}")

    # Download về máy
    from google.colab import files
    files.download(filename)

# Ví dụ lưu recipe1
# save_recipe_to_file(recipe1, "labubu_cake_recipe.txt")

# ✅ Bước 9: Demo function kết hợp
def create_full_bakery_content(trend, user_segment, occasion="everyday"):
    """Tạo full content cho 1 sản phẩm bánh"""
    print(f"\n🎨 Đang tạo content cho: {trend} - {user_segment}")

    # Tạo công thức
    recipe = generate_recipe_from_trend(trend, user_segment, occasion)

    # Tạo thêm content marketing
    model = genai.GenerativeModel('gemini-2.5-pro')
    marketing_prompt = f"""
Dựa trên công thức bánh về {trend} cho {user_segment}, hãy tạo:
1. 3 hashtag trending cho Instagram/TikTok
2. Mô tả sản phẩm ngắn gọn cho menu (50 từ)
3. Giá bán đề xuất (VNĐ) phù hợp với thị trường Việt Nam
"""

    marketing_content = model.generate_content(marketing_prompt)

    return {
        "recipe": recipe,
        "marketing": marketing_content.text
    }

# Test function kết hợp
print("\n" + "=" * 50)
print("🎯 TEST 5: Tạo Full Content")
print("=" * 50)

full_content = create_full_bakery_content(
    trend="Matcha x Sakura",
    user_segment="Phụ nữ công sở thích phong cách Nhật",
    occasion="8/3"
)

print("📋 CÔNG THỨC:")
print(full_content["recipe"][:800] + "...")
print("\n📱 MARKETING CONTENT:")
print(full_content["marketing"])

print("\n" + "=" * 50)
print("✅ HOÀN TẤT TESTING!")
print("=" * 50)
# Out:
# ==================================================
# 🧪 TEST 1: Kiểm tra kết nối Gemini
# ==================================================
# 🤖 Gemini response: Of course! I'd be happy to help.
#
# What can I do for you today? Just let me know what you need....
#
# ==================================================
# 🎂 TEST 2: Tạo công thức theo TREND
# ==================================================
# Tuyệt vời! Với vai trò là một đầu bếp bánh ngọt và chuyên gia marketing, tôi sẽ "bếp núc" ngay một công thức không chỉ ngon miệng mà còn "đốn tim" GenZ và bắt trọn trend Labubu.
#
# ---
#
# ### **1. TÊN BÁNH: Bubu Mộng Mơ (Dreamy Bubu)**
#
# *Lý do chọn tên:* "Bubu" là cách gọi thân mật, đáng yêu của Labubu. "Mộng Mơ" gợi liên tưởng đến những đám mây bồng bềnh, dải màu pastel ngọt ngào, phù hợp với thẩm mỹ của GenZ và concept của chiếc bánh.
#
# ---
#
# ### **2. MÔ TẢ BÁNH**
#
# Lấy cảm hứng từ nhân vật Labubu tinh nghịch, **Bubu Mộng Mơ** là một bản giao hưởng ngọt ngào của những tầng hương vị. Cốt bánh bông lan vani mềm mịn như mây, ôm ấp lớp mousse dâu tây phô mai chua dịu, tan chảy cùng nhân mứt phúc bồn tử "gây thương nhớ" ở trung tâm. Chiếc bánh là món quà sinh nhật hoàn hảo để "flex" trên mạng xã hội và mang lại niềm vui bất ngờ cho các fan cứng của Labubu.
#
# ---
#
# ### **3. NGUYÊN LIỆU**
#
# *(Công thức cho khuôn tròn 16cm, cao 8cm - size phổ biến cho tiệm bánh nhỏ)*
#
# **A. Cốt Bánh Bông Lan Vani (Genoise)**
# *   Trứng gà (nhiệt độ phòng): 3 quả (khoảng 150g)
# *   Đường cát: 90g
# *   Bột mì số 8 (cake flour): 90g
# *   Bơ lạt (đun chảy): 25g
# *   Sữa tươi không đường: 25ml
# *   Chiết xuất vani: 5ml
#
# **B. Nhân Mứt Phúc Bồn Tử (Raspberry Compote)**
# *   Phúc bồn tử tươi/đông lạnh: 150g
# *   Đường: 40g
# *   Nước cốt chanh: 5ml
# *   Gelatin (dạng lá): 2g
#
# **C. Mousse Dâu Tây Phô Mai**
# *   Dâu tây tươi (xay nhuyễn): 150g
# *   Cream cheese: 200g
# *   Whipping cream 35% béo: 250ml
# *   Đường bột: 60g
# *   Gelatin (dạng lá): 6g
#
# **D. Kem Bơ Thụy Sĩ (Swiss Meringue Buttercream) để chà láng & trang trí**
# *   Lòng trắng trứng: 100g (khoảng 3 lòng trắng)
# *   Đường cát: 200g
# *   Bơ lạt (để mềm ở nhiệt độ phòng): 250g
# *   Chiết xuất vani: 5ml
# *   Màu thực phẩm dạng gel (hồng pastel, xanh mint, tím lavender)
#
# ---
#
# ### **4. CÁCH LÀM**
#
# **Bước 1: Làm nhân mứt (chuẩn bị trước 1 ngày hoặc ít nhất 4 tiếng)**
# 1.  Ngâm lá gelatin vào nước đá cho mềm.
# 2.  Cho phúc bồn tử và đường vào nồi, sên ở lửa vừa đến khi hỗn hợp sệt lại. Thêm nước cốt chanh.
# 3.  Tắt bếp, vắt ráo gelatin rồi cho vào hỗn hợp mứt còn nóng, khuấy đều cho tan hoàn toàn.
# 4.  Đổ mứt vào khuôn tròn 12cm (nhỏ hơn khuôn bánh), bọc kín và để tủ đông cho đến khi đông cứng.
#
# **Bước 2: Nướng cốt bánh**
# 1.  Làm nóng lò ở 170°C. Lót giấy nến cho đáy khuôn 16cm.
# 2.  Đánh bông trứng và đường bằng máy đánh trứng ở tốc độ cao cho đến khi hỗn hợp bông đặc, có màu vàng nhạt, nhấc phới lên thấy hỗn hợp chảy thành dòng như ruy băng.
# 3.  Rây bột mì vào hỗn hợp trứng, dùng phới dẹt trộn nhẹ nhàng theo kỹ thuật fold (gấp từ dưới lên) để tránh làm vỡ bọt khí.
# 4.  Trộn đều bơ chảy, sữa tươi và vani trong một tô riêng. Múc một muỗng bột lớn từ hỗn hợp chính vào tô bơ sữa, khuấy đều cho hòa quyện (để làm loãng bơ, tránh bị chìm khi trộn vào bột chính).
# 5.  Đổ ngược hỗn hợp bơ sữa vào tô bột chính, fold nhẹ nhàng lần cuối.
# 6.  Đổ bột vào khuôn, nướng 30-35 phút. Thử bánh bằng cách xiên tăm, tăm rút ra khô ráo là bánh chín.
# 7.  Để bánh nguội hoàn toàn trên rack. Sau đó xẻ bánh thành 3 lớp bằng nhau.
#
# **Bước 3: Làm Mousse và Lắp Ráp Bánh**
# 1.  Ngâm lá gelatin vào nước đá.
# 2.  Đánh mềm cream cheese với đường bột. Cho dâu tây xay nhuyễn vào trộn đều.
# 3.  Đun cách thủy gelatin đã ngâm mềm cho tan chảy. Lấy một ít hỗn hợp cream cheese trộn với gelatin trước, sau đó đổ ngược lại vào tô cream cheese, trộn đều.
# 4.  Đánh bông whipping cream đến khi bông mềm, có chóp cong.
# 5.  Trộn nhẹ nhàng whipping cream đã đánh bông vào hỗn hợp cream cheese dâu tây.
# 6.  **Lắp ráp:** Dùng khuôn 16cm có lót màng acetate xung quanh. Đặt lớp bánh đầu tiên xuống đáy. Phun một lớp mousse. Đặt nhân mứt phúc bồn tử đã đông cứng vào giữa. Phun thêm một lớp mousse che kín nhân. Đặt lớp bánh thứ hai lên, phun mousse và cuối cùng là lớp bánh thứ ba.
# 7.  Để bánh vào tủ lạnh ít nhất 4-6 tiếng (tốt nhất là qua đêm) cho bánh định hình.
#
# **Bước 4: Hoàn thiện**
# 1.  **Làm kem bơ Thụy Sĩ:** Đánh cách thủy lòng trắng trứng và đường đến khi đường tan hết (khoảng 60°C). Chuyển sang máy đánh trứng, đánh ở tốc độ cao đến khi hỗn hợp bông cứng, bóng dẻo và tô nguội hoàn toàn. Giảm tốc độ, cho từng muỗng bơ mềm vào đánh đều. Cuối cùng cho vani vào.
# 2.  Lấy bánh ra khỏi khuôn. Chà láng một lớp kem mỏng (crumb coat) để giữ vụn bánh, làm lạnh 15 phút.
# 3.  Pha kem bơ thành các màu pastel. Chà láng lớp kem hoàn thiện bên ngoài.
#
# ---
#
# ### **5. GỢI Ý TRANG TRÍ (TRENDY & CUTE)**
#
# *   **Vẽ mặt Labubu:** Dùng chocolate đen đun chảy cho vào túi bắt kem đầu nhỏ để vẽ mắt và miệng đặc trưng của Labubu lên mặt bánh. Đây là cách đơn giản và hiệu quả nhất.
# *   **Tai Labubu:** Dùng fondant màu hồng pastel hoặc màu trắng cán mỏng, cắt thành hình 2 chiếc tai thỏ dài, cắm lên trên đỉnh bánh.
# *   **Hiệu ứng Mây Bồng Bềnh:** Dùng các màu kem bơ pastel khác nhau (xanh, tím, hồng), cho vào túi bắt kem dùng đui tròn, bơm thành những cụm "mây" nhỏ xinh xung quanh chân bánh hoặc trên đỉnh bánh.
# *   **Topping "Lấp Lánh":** Rắc thêm một ít cốm bi nhiều màu pastel, hạt đường lấp lánh (edible glitter) hoặc kẹo ngọc trai để tăng thêm phần "mộng mơ".
# *   **Option nâng cao:** Đặt một mô hình Labubu Macaron (phiên bản đang hot) real size lên trên bánh làm điểm nhấn (ghi chú cho khách đây là mô hình không ăn được).
#
#
#  *(Imagine a pastel cake with Labubu's face drawn on it, fondant ears, and cloudy buttercream puffs around it)*
#
# ---
#
# ### **6. CAPTION FACEBOOK (VIRAL)**
#
# 🎂✨ **SINH NHẬT NÀY "ĐU" TREND LABUBU CÙNG "BUBU MỘNG MƠ"** ✨🎂
#
# Alo alo, fan cứng của bé quỷ răng thỏ đâu rồiii? 🙋‍♀️🙋‍♂️
#
# Quên đi những chiếc bánh sinh nhật cũ kỹ, tiệm chúng mình vừa cho ra mắt siêu phẩm **Bubu Mộng Mơ** độc quyền dành riêng cho GenZ!
#
# ☁️ Bên ngoài là "visual" pastel xinh xỉu với gương mặt Labubu cute lạc lối.
# 🍓 Bên trong là sự bùng nổ của cốt bánh vani mềm ẩm, mousse dâu phô mai chua ngọt và nhân phúc bồn tử bí mật. Ăn là chỉ có mê chữ ê kéo dàiiii~
#
# Tag ngay đứa bạn thân sắp tới sinh nhật mà cũng u mê Labubu vào đây để "nhắc nhẹ" nào! Inbox cho tụi mình để rước ngay một bé Bubu về thổi nến nhé! 💖
#
# #BubuMongMo #LabubuCake #BanhSinhNhatLabubu #TiemBanhNhaMinh #BanhKemGenZ #PastelCake #CuteCake #HappyBirthday #LabubuTrend
#
# ==================================================
# 🥧 TEST 3: Tạo công thức từ NGUYÊN LIỆU
# ==================================================
# Chắc chắn rồi! Dựa trên những nguyên liệu bạn cung cấp, đây là một công thức bánh ngọt cực kỳ đơn giản, dễ thành công, phù hợp cho những người mới bắt đầu.
#
# ---
#
# ### **1. Tên món: BÁNH BÔNG LAN BƠ SỮA VANI**
# *(Công thức cơ bản và thơm ngon)*
#
# Công thức này tạo ra một chiếc bánh mềm ẩm, thơm lừng mùi bơ và vani, là món bánh hoàn hảo để thưởng thức cùng trà hoặc cà phê.
#
# ### **2. Các bước thực hiện chi tiết**
#
# **Phần chuẩn bị nguyên liệu (đong đếm chính xác):**
#
# *   **Bột mì đa dụng:** 150g
# *   **Baking powder (bột nở):** 5g (khoảng 1 thìa cà phê đầy)
# *   **Bơ lạt (để mềm ở nhiệt độ phòng):** 100g
# *   **Đường cát trắng:** 100g (có thể gia giảm nếu thích ít ngọt)
# *   **Trứng gà (để ở nhiệt độ phòng):** 2 quả lớn
# *   **Sữa tươi không đường:** 60ml
# *   **Chiết xuất vani:** 5ml (1 thìa cà phê)
# *   **Muối:** 1 nhúm nhỏ (khoảng 1/4 thìa cà phê)
#
# **Dụng cụ:**
# *   Lò nướng
# *   Khuôn tròn 20cm hoặc khuôn loaf (khuôn chữ nhật)
# *   Máy đánh trứng (hoặc phới lồng)
# *   Tô trộn bột, rây bột
#
# **Các bước thực hiện:**
#
# *   **Bước 1: Chuẩn bị**
#     *   Làm nóng lò nướng trước ở nhiệt độ **175°C** (chế độ 2 lửa trên dưới).
#     *   Chống dính cho khuôn: Quét một lớp bơ mỏng quanh lòng khuôn rồi rắc một lớp bột mì mỏng, hoặc lót giấy nến cho tiện lợi.
#     *   Trong một tô, dùng rây để rây mịn hỗn hợp **bột mì, baking powder và muối**. Trộn đều và để sang một bên. Việc này giúp bánh nở đều và không bị vón cục.
#
# *   **Bước 2: Đánh bơ đường**
#     *   Trong một tô lớn khác, cho **bơ lạt đã để mềm** và **đường** vào.
#     *   Dùng máy đánh trứng đánh ở tốc độ trung bình trong khoảng 3-5 phút cho đến khi hỗn hợp bông xốp, chuyển sang màu vàng nhạt. Đây là bước quan trọng nhất để tạo độ mềm xốp cho bánh.
#
# *   **Bước 3: Thêm trứng và vani**
#     *   Cho từng quả **trứng** vào hỗn hợp bơ đường. Đánh tan hoàn toàn quả trứng thứ nhất rồi mới cho quả thứ hai vào. Việc này giúp hỗn hợp không bị tách nước (lợn cợn).
#     *   Sau khi trứng đã hòa quyện, cho **chiết xuất vani** vào và đánh sơ khoảng 15 giây.
#
# *   **Bước 4: Trộn bột và sữa**
#     *   Chia hỗn hợp bột khô (ở Bước 1) làm 3 phần, sữa tươi làm 2 phần.
#     *   Lần lượt cho xen kẽ bột và sữa vào tô bơ trứng, trộn ở tốc độ thấp nhất:
#         *   Cho **1/3 lượng bột**, trộn đều.
#         *   Cho **1/2 lượng sữa**, trộn đều.
#         *   Cho **1/3 lượng bột**, trộn đều.
#         *   Cho **1/2 lượng sữa còn lại**, trộn đều.
#         *   Cho **1/3 lượng bột cuối cùng**, trộn đến khi vừa hòa quyện.
#     *   *Lưu ý:* Không trộn bột quá lâu, chỉ trộn đến khi không còn thấy bột khô là dừng để tránh bánh bị chai, cứng.
#
# *   **Bước 5: Đổ khuôn và nướng**
#     *   Đổ hỗn hợp bột vào khuôn đã chuẩn bị, dùng phới dẹt (spatula) dàn cho bề mặt phẳng.
#     *   Đặt khuôn vào rãnh giữa của lò nướng đã được làm nóng sẵn.
#
# ### **3. Thời gian và nhiệt độ nướng**
#
# *   **Nhiệt độ:** **175°C** (chế độ 2 lửa trên dưới, không dùng quạt đối lưu).
# *   **Thời gian:** Nướng trong khoảng **30 - 40 phút**.
# *   **Cách kiểm tra bánh chín:** Sau 30 phút, dùng một que tăm xiên vào chính giữa bánh. Nếu rút tăm ra thấy khô ráo, không dính bột ướt là bánh đã chín. Nếu tăm còn ướt, nướng thêm 5-7 phút nữa rồi kiểm tra lại.
# *   **Làm nguội:** Khi bánh chín, lấy ra khỏi lò, để bánh trong khuôn khoảng 10 phút rồi mới nhẹ nhàng lấy bánh ra đặt lên rack cho nguội hoàn toàn.
#
# ### **4. Lưu ý quan trọng**
#
# 1.  **Nhiệt độ nguyên liệu:** Đây là yếu tố quyết định! **Bơ và trứng PHẢI để ở nhiệt độ phòng**. Bơ quá lạnh sẽ không bông, bơ quá chảy sẽ làm bánh bị bết. Trứng lạnh sẽ làm hỗn hợp bị tách nước.
# 2.  **Không trộn bột quá tay:** Sau khi cho bột mì vào, chỉ nên trộn ở tốc độ thấp và dừng ngay khi bột vừa hòa quyện. Trộn quá lâu sẽ kích thích gluten phát triển, làm bánh bị dai và chai cứng thay vì mềm xốp.
# 3.  **Làm nóng lò trước:** Luôn đảm bảo lò đạt đúng nhiệt độ yêu cầu trước khi cho bánh vào nướng.
# 4.  **Rây bột:** Đừng bỏ qua bước này. Rây bột giúp các nguyên liệu khô trộn đều, loại bỏ vón cục và giúp bánh có kết cấu mịn màng hơn.
# 5.  **Tùy chỉnh:** Bạn có thể thêm vỏ chanh vàng bào, một ít mứt trái cây, hoặc chocolate chips vào bước trộn bột cuối cùng để tạo ra hương vị mới lạ.
#
# Chúc bạn thành công với món bánh bông lan thơm ngon này
#
# ==================================================
# 🌟 TEST 4: Các scenarios khác nhau
# ==================================================
#
# --- Scenario 1: Doraemon ---
# Tuyệt vời! Với vai trò là một bếp trưởng bánh ngọt và chuyên gia marketing, tôi rất hào hứng với nhiệm vụ này. Doraemon và Trung Thu là một sự kết hợp hoàn hảo để chinh phục trái tim các bạn nhỏ và cả những bậc phụ huynh hoài niệm.
#
# Dưới đây là công thức và kế hoạch marketing chi tiết.
#
# ---
#
# ### **1. TÊN BÁNH: TRĂNG RẰM BẢO BỐI**
#
# *   **Ý nghĩa:** Tên gọi kết hợp hình ảnh "Trăng Rằm" của Trung Thu và "Bảo Bối" từ chiếc túi thần kỳ của Doraemon. Nó gợi lên sự kỳ diệu, bất ngờ và một món quà quý g...
#
#
# --- Scenario 2: Minimalist, healthy ---
# Tuyệt vời! Với vai trò là một đầu bếp bánh ngọt và chuyên gia marketing, tôi sẽ tạo ra một sản phẩm không chỉ ngon miệng, lành mạnh mà còn có sức hút mạnh mẽ trên thị trường.
#
# Dưới đây là công thức và kế hoạch marketing chi tiết cho món bánh của chúng ta.
#
# ---
#
# ### **1. TÊN BÁNH: Lean Cloud Mousse**
#
# *   **Tên phụ (tiếng Việt):** Mây Mịn Năng Lượng
# *   **Lý do chọn tên:**
#     *   **Lean:** Từ khóa đắt giá với dân gym và người ăn kiêng, có nghĩa là "săn chắc", "không mỡ thừa".
#     *   **Cloud:** ...
#
#
# --- Scenario 3: Hoa anh đào Nhật Bản ---
# Tuyệt vời! Với vai trò là một đầu bếp bánh ngọt và chuyên gia marketing, tôi sẽ tạo ra một sản phẩm không chỉ ngon miệng, đẹp mắt mà còn có câu chuyện để chinh phục trái tim khách hàng của bạn.
#
# Dưới đây là công thức và kế hoạch marketing hoàn chỉnh cho chiếc bánh Valentine theo chủ đề hoa anh đào.
#
# ---
#
# ### **1. TÊN BÁNH: SAKURA HIKARI (Tình Yêu Tỏa Nắng)**
#
# *   **Lý do chọn tên:** "Sakura" (anh đào) là tên chủ đạo. "Hikari" (光) trong tiếng Nhật có nghĩa là "ánh sáng". Cái tên gợi lên hình ảnh ...
#
#
# ==================================================
# 🎮 INTERACTIVE MODE
# ==================================================
#
# ==================================================
# 🎯 TEST 5: Tạo Full Content
# ==================================================
#
# 🎨 Đang tạo content cho: Matcha x Sakura - Phụ nữ công sở thích phong cách Nhật
# 📋 CÔNG THỨC:
# Chắc chắn rồi! Với vai trò là một đầu bếp bánh ngọt và chuyên gia marketing, tôi sẽ tạo ra một sản phẩm hoàn hảo để chinh phục những quý cô công sở trong dịp 8/3 này.
#
# Dưới đây là công thức và kế hoạch marketing chi tiết cho món bánh đặc biệt.
#
# ---
#
# ### **1. TÊN BÁNH: KYOTO IN BLOOM**
#
# *   **Tên phụ (Tiếng Việt):** Khúc Giao Mùa Anh Đào & Trà Xanh
# *   **Lý do chọn tên:** "Kyoto in Bloom" gợi lên hình ảnh Kyoto bừng nở trong mùa hoa anh đào, một cái tên quốc tế, sang trọng và dễ nhớ. Tên phụ tiếng Việt vừa thơ mộng, vừa miêu tả rõ ràng hai thành phần chính, đánh trúng tâm lý yêu thích văn hóa Nhật của khách hàng.
#
# ### **2. MÔ TẢ SẢN PHẨM**
#
# **Kyoto in Bloom** là bản giao hưởng tinh tế của mùa xuân Nhật Bản, gói trọn trong từng lớp bánh mềm mịn. Vị đắng thanh sâu lắng của matcha Uji hảo hạng...
#
# 📱 MARKETING CONTENT:
# Tuyệt vời! Dựa trên ý tưởng một chiếc bánh tinh tế, kết hợp giữa vị đậm đà của matcha và hương thơm dịu dàng của hoa anh đào, dành riêng cho các quý cô công sở yêu phong cách Nhật, đây là các gợi ý chi tiết:
#
# ---
#
# ### **1. Hashtag trending cho Instagram/TikTok**
#
# Đây là 3 hashtag được thiết kế để vừa mô tả sản phẩm, vừa gợi cảm xúc và bắt trend "chữa lành" (healing) đang rất thịnh hành.
#
# 1.  **#MatchaGiuMuaXuan**
#     *   **Lý do:** Gợi hình ảnh thơ mộng, lãng mạn. "Giữ mùa xuân" mang ý nghĩa lưu giữ khoảnh khắc đẹp, thanh tao của hoa anh đào. Hashtag này rất "thơ" và dễ tạo thành một trào lưu chụp ảnh/quay video nghệ thuật.
#
# 2.  **#VuonNhatTrongChiecBanh**
#     *   **Lý do:** Kích thích trí tưởng tượng và sự tò mò. Nó gợi lên hình ảnh một chiếc bánh được chế tác tỉ mỉ, tinh xảo như một khu vườn Nhật thu nhỏ. Hashtag này nhấn mạnh vào yếu tố thẩm mỹ, rất phù hợp với Instagram.
#
# 3.  **#HealingCungMatchaSakura**
#     *   **Lý do:** Đánh thẳng vào tâm lý của phụ nữ công sở – tìm kiếm sự thư giãn, "chữa lành" sau những giờ làm việc căng thẳng. Việc kết hợp từ tiếng Anh "Healing" đang là xu hướng, tạo cảm giác hiện đại và dễ tiếp cận.
#
# ### **2. Mô tả sản phẩm ngắn gọn cho menu (dưới 50 từ)**
#
# **Matcha Sakura - "Mùa Xuân Dịu Êm"**
#
# Cốt bánh matcha Uji đậm vị, mềm xốp, quyện cùng lớp kem hoa anh đào thơm dịu, ngọt thanh. Một sự kết hợp tinh tế, mang cả hương vị mùa xuân Nhật Bản nhẹ nhàng, thanh tao vào trong từng miếng bánh.
#
# ### **3. Giá bán đề xuất (VNĐ)**
#
# Để định vị sản phẩm là một món bánh cao cấp, tinh tế, sử dụng nguyên liệu chất lượng (matcha Uji, chiết xuất hoa anh đào) và hướng đến đối tượng có thu nhập, mức giá cần phản ánh đúng giá trị đó.
#
# *   **Giá bán theo miếng (slice):** **85.000 VNĐ - 95.000 VNĐ / miếng**
#     *   Mức giá này tương xứng với các dòng bánh artisan, bánh Âu tại các quán cà phê, tiệm bánh lớn ở các thành phố như Hà Nội, TP.HCM. Nó tạo cảm giác đây là một phần thưởng nhỏ nhưng xứng đáng.
# *   **Giá bán nguyên ổ (whole cake - size 16-18cm):** **650.000 VNĐ - 750.000 VNĐ / ổ**
#     *   Phù hợp cho các dịp đặc biệt, liên hoan nhỏ tại văn phòng hoặc làm quà tặng.
#
# ==================================================
# ✅ HOÀN TẤT TESTING!
# ==================================================
